# %% [markdown]
# # ***Import Libraries***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import keras
from tqdm import tqdm
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ***Reading Data***

# %%
folder=os.listdir('/kaggle/input/brain-tumor-segmentation')
folder.sort()
folder
# Out:
# ['images', 'masks']

# %%
# Sort the image and mask filenames to ensure they match
image_files = sorted(os.listdir('/kaggle/input/brain-tumor-segmentation/images'))
mask_files = sorted(os.listdir('/kaggle/input/brain-tumor-segmentation/masks'))

print(image_files[:5])
print("=================")
print(mask_files[:5])
# Out:
# ['1.png', '10.png', '100.png', '1000.png', '1001.png']
# =================
# ['1.png', '10.png', '100.png', '1000.png', '1001.png']

# %%
def display_images_masks(imagepath, maskpath):

        count = 0

        for image_file, mask_file in zip(image_files, mask_files):

            if count >= 4:  # Display only the first 4 images from each folder
                break


            imagepath_full = os.path.join(imagepath, image_file)
            maskpath_full = os.path.join(maskpath, mask_file)

            image = cv2.imread(imagepath_full)
            mask = cv2.imread(maskpath_full)

            if image is None:
                raise ValueError(f"Image at path {imagepath_full} could not be loaded")
            if mask is None:
                raise ValueError(f"Mask at path {maskpath_full} could not be loaded")

            plt.figure(figsize=(10, 10))

            # First subplot (image)
            plt.subplot(1, 3, 1)
            plt.imshow(image)
            plt.title('Image')

            # Second subplot (mask)
            plt.subplot(1, 3, 2)
            plt.imshow(mask)
            plt.title('Mask')

            # Third subplot (Image with Contours)
            plt.subplot(1, 3, 3)

            sample = np.array(np.squeeze(mask), dtype = np.uint8)
            contours, hier = cv2.findContours(sample[:,:,1],cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)
            sample_over_gt = cv2.drawContours(image, contours, -1,[0,255,0], thickness=-1)
            plt.imshow(sample_over_gt)
            plt.title('Image with Contours')


            plt.show()
            count += 1

# %%
IMAGES_PATH='/kaggle/input/brain-tumor-segmentation/images'
MASKS_PATH='/kaggle/input/brain-tumor-segmentation/masks'

SIZE=256
CHANNEL=1

Num_Of_Classes=1

# %%
display_images_masks(IMAGES_PATH,MASKS_PATH)

# %% [markdown]
# # ***Show Different Size of Images***

# %%
images_size=[]
masks_size=[]

for image_file, mask_file in tqdm(zip(image_files, mask_files)):


    imagepath_full = os.path.join(IMAGES_PATH, image_file)
    maskpath_full = os.path.join(MASKS_PATH, mask_file)

    image = cv2.imread(imagepath_full)
    mask = cv2.imread(maskpath_full)

    images_size.append(image.shape)
    masks_size.append(mask.shape)
# Out:
# 3064it [00:43, 70.77it/s]

# %%
print(list(set(images_size)))
print("=================")
print(list(set(masks_size)))
# Out:
# [(512, 512, 3), (256, 256, 3)]
# =================
# [(512, 512, 3), (256, 256, 3)]

# %% [markdown]
# # ***Preprocessing Images & Masks***

# %%
def preprocessing_images_masks():
    images=[]
    masks=[]

    for image_file, mask_file in tqdm(zip(image_files, mask_files)):


        imagepath_full = os.path.join(IMAGES_PATH, image_file)
        maskpath_full = os.path.join(MASKS_PATH, mask_file)

        image = cv2.imread(imagepath_full,cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image,(SIZE,SIZE))
        image = image/255.0
        images.append(image)

        mask = cv2.imread(maskpath_full,cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask,(SIZE,SIZE))
        mask = mask/255.0
        masks.append(mask)

    return np.expand_dims(np.array(images), axis=-1), np.expand_dims(np.array(masks), axis=-1)

# %%
X,y=preprocessing_images_masks()
# Out:
# 3064it [00:18, 164.04it/s]

# %%
print('The Shape of X',X.shape)
print('The Shape of y',y.shape)
# Out:
# The Shape of X (3064, 256, 256, 1)
# The Shape of y (3064, 256, 256, 1)

# %% [markdown]
# # ***Split Data into Training & Testing***

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print('The shape of X_train',X_train.shape)
print('The shape of y_train',y_train.shape)
print('The shape of X_test',X_test.shape)
print('The shape of y_test',y_test.shape)
# Out:
# The shape of X_train (2451, 256, 256, 1)
# The shape of y_train (2451, 256, 256, 1)
# The shape of X_test (613, 256, 256, 1)
# The shape of y_test (613, 256, 256, 1)

# %% [markdown]
# # ***Defineing Loss Function and Metrics***

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# # ***Build U-Net Architecture***

# %% [markdown]
# ***Overview***
#
#  U-Net is a convolutional neural network architecture designed for biomedical image segmentation. It was proposed by Olaf Ronneberger et al. in 2015. The architecture is particularly effective for tasks where precise localization of features is required, such as in medical imaging, but has also been successfully applied to various other segmentation tasks.
#
# ***Architecture***
# * Contracting Path (Encoder): This part captures context through a series of convolutional and max-pooling layers, progressively reducing the spatial dimensions of the feature maps.
# * Expanding Path (Decoder): This part enables precise localization through upsampling and concatenation of feature maps from the contracting path.

# %% [markdown]
# ![u-net-architecture.png](attachment:94465044-b40d-4d73-b820-59bf3cc992a8.png)

# %%
def unet_model(input_size=(SIZE, SIZE, CHANNEL), num_classes=Num_Of_Classes):
    inputs = keras.layers.Input(input_size)

    # Encoding (Downsampling)
    c1 = keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = keras.layers.MaxPooling2D((2, 2))(c2)

    c3 = keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = keras.layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = keras.layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = keras.layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    # Decoding (Upsampling)
    u6 = keras.layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = keras.layers.concatenate([u6, c4])
    c6 = keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = keras.layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = keras.layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = keras.layers.concatenate([u7, c3])
    c7 = keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = keras.layers.concatenate([u8, c2])
    c8 = keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = keras.layers.concatenate([u9, c1], axis=3)
    c9 = keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    # Output layer
    outputs = keras.layers.Conv2D(num_classes, (1, 1), activation='sigmoid')(c9)

    model = keras.models.Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
# Create and compile the model
model = unet_model(input_size=(SIZE, SIZE,CHANNEL), num_classes=Num_Of_Classes)

model.compile(optimizer=Adam(learning_rate=1e-5), loss=dice_loss, metrics=['accuracy',dice_coef])

# %%
# Summary of the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ conv2d_8[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  2,097,664 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    524,544 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_16[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,030,593 (118.37 MB)
#  Trainable params: 31,030,593 (118.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
ealystopping=tf.keras.callbacks.EarlyStopping(patience=20,
                                            monitor='val_accuracy',
                                            restore_best_weights=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                 factor=0.2, 
                                                 patience=15, 
                                                 min_lr=1e-7, 
                                                 mode='min')

# %%
history=model.fit(X_train, y_train, batch_size=32, epochs=100,validation_data=(X_test, y_test),
          verbose=1, callbacks=[ealystopping,reduce_lr])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728165578.960737     127 service.cc:145] XLA service 0x7cf2ec0080a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1
# Epoch 70/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 666ms/step - accuracy: 0.9958 - dice_coef: 0.8902 - loss: 0.1098 - val_accuracy: 0.9916 - val_dice_coef: 0.7112 - val_loss: 0.2937 - learning_rate: 1.0000e-05
# Epoch 71/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9961 - dice_coef: 0.8968 - loss: 0.1032 - val_accuracy: 0.9913 - val_dice_coef: 0.7392 - val_loss: 0.2649 - learning_rate: 1.0000e-05
# Epoch 72/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9959 - dice_coef: 0.8923 - loss: 0.1077 - val_accuracy: 0.9908 - val_dice_coef: 0.7322 - val_loss: 0.2711 - learning_rate: 1.0000e-05
# Epoch 73/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9962 - dice_coef: 0.9008 - loss: 0.0992 - val_accuracy: 0.9912 - val_dice_coef: 0.7353 - val_loss: 0.2683 - learning_rate: 1.0000e-05
# Epoch 74/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9962 - dice_coef: 0.9036 - loss: 0.0964 - val_accuracy: 0.9915 - val_dice_coef: 0.7167 - val_loss: 0.2877 - learning_rate: 1.0000e-05
# Epoch 75/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 666ms/step - accuracy: 0.9963 - dice_coef: 0.9037 - loss: 0.0963 - val_accuracy: 0.9916 - val_dice_coef: 0.7332 - val_loss: 0.2714 - learning_rate: 1.0000e-05
# Epoch 76/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9964 - dice_coef: 0.9085 - loss: 0.0915 - val_accuracy: 0.9914 - val_dice_coef: 0.7365 - val_loss: 0.2677 - learning_rate: 1.0000e-05
# Epoch 77/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9964 - dice_coef: 0.9086 - loss: 0.0914 - val_accuracy: 0.9916 - val_dice_coef: 0.7307 - val_loss: 0.2736 - learning_rate: 1.0000e-05
# Epoch 78/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 666ms/step - accuracy: 0.9963 - dice_coef: 0.9071 - loss: 0.0929 - val_accuracy: 0.9917 - val_dice_coef: 0.7352 - val_loss: 0.2696 - learning_rate: 1.0000e-05
# Epoch 79/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9966 - dice_coef: 0.9149 - loss: 0.0851 - val_accuracy: 0.9911 - val_dice_coef: 0.7399 - val_loss: 0.2653 - learning_rate: 1.0000e-05
# Epoch 80/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9966 - dice_coef: 0.9167 - loss: 0.0833 - val_accuracy: 0.9914 - val_dice_coef: 0.7433 - val_loss: 0.2617 - learning_rate: 1.0000e-05
# Epoch 81/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9966 - dice_coef: 0.9149 - loss: 0.0851 - val_accuracy: 0.9899 - val_dice_coef: 0.7239 - val_loss: 0.2817 - learning_rate: 1.0000e-05
# Epoch 82/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9959 - dice_coef: 0.8951 - loss: 0.1049 - val_accuracy: 0.9914 - val_dice_coef: 0.7382 - val_loss: 0.2673 - learning_rate: 1.0000e-05
# Epoch 83/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9965 - dice_coef: 0.9145 - loss: 0.0855 - val_accuracy: 0.9915 - val_dice_coef: 0.7412 - val_loss: 0.2640 - learning_rate: 1.0000e-05
# Epoch 84/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9967 - dice_coef: 0.9188 - loss: 0.0812 - val_accuracy: 0.9916 - val_dice_coef: 0.7447 - val_loss: 0.2595 - learning_rate: 1.0000e-05
# Epoch 85/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9967 - dice_coef: 0.9198 - loss: 0.0802 - val_accuracy: 0.9913 - val_dice_coef: 0.7417 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 86/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9969 - dice_coef: 0.9253 - loss: 0.0747 - val_accuracy: 0.9908 - val_dice_coef: 0.7367 - val_loss: 0.2685 - learning_rate: 1.0000e-05
# Epoch 87/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9968 - dice_coef: 0.9217 - loss: 0.0783 - val_accuracy: 0.9905 - val_dice_coef: 0.7261 - val_loss: 0.2786 - learning_rate: 1.0000e-05
# Epoch 88/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9965 - dice_coef: 0.9129 - loss: 0.0871 - val_accuracy: 0.9917 - val_dice_coef: 0.7422 - val_loss: 0.2623 - learning_rate: 1.0000e-05
# Epoch 89/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 52s 682ms/step - accuracy: 0.9968 - dice_coef: 0.9237 - loss: 0.0763 - val_accuracy: 0.9915 - val_dice_coef: 0.7370 - val_loss: 0.2677 - learning_rate: 1.0000e-05
# Epoch 90/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 666ms/step - accuracy: 0.9970 - dice_coef: 0.9287 - loss: 0.0713 - val_accuracy: 0.9918 - val_dice_coef: 0.7396 - val_loss: 0.2646 - learning_rate: 1.0000e-05
# Epoch 91/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9971 - dice_coef: 0.9302 - loss: 0.0698 - val_accuracy: 0.9918 - val_dice_coef: 0.7400 - val_loss: 0.2650 - learning_rate: 1.0000e-05
# Epoch 92/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9971 - dice_coef: 0.9317 - loss: 0.0683 - val_accuracy: 0.9915 - val_dice_coef: 0.7433 - val_loss: 0.2615 - learning_rate: 1.0000e-05
# Epoch 93/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9972 - dice_coef: 0.9328 - loss: 0.0672 - val_accuracy: 0.9916 - val_dice_coef: 0.7400 - val_loss: 0.2640 - learning_rate: 1.0000e-05
# Epoch 94/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9971 - dice_coef: 0.9302 - loss: 0.0698 - val_accuracy: 0.9910 - val_dice_coef: 0.7415 - val_loss: 0.2636 - learning_rate: 1.0000e-05
# Epoch 95/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9972 - dice_coef: 0.9323 - loss: 0.0677 - val_accuracy: 0.9917 - val_dice_coef: 0.7421 - val_loss: 0.2625 - learning_rate: 1.0000e-05
# Epoch 96/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9973 - dice_coef: 0.9360 - loss: 0.0640 - val_accuracy: 0.9911 - val_dice_coef: 0.7380 - val_loss: 0.2677 - learning_rate: 1.0000e-05
# Epoch 97/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9972 - dice_coef: 0.9321 - loss: 0.0679 - val_accuracy: 0.9918 - val_dice_coef: 0.7467 - val_loss: 0.2576 - learning_rate: 1.0000e-05
# Epoch 98/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9972 - dice_coef: 0.9341 - loss: 0.0659 - val_accuracy: 0.9917 - val_dice_coef: 0.7277 - val_loss: 0.2759 - learning_rate: 1.0000e-05
# Epoch 99/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9971 - dice_coef: 0.9289 - loss: 0.0711 - val_accuracy: 0.9913 - val_dice_coef: 0.7397 - val_loss: 0.2653 - learning_rate: 1.0000e-05
# Epoch 100/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 665ms/step - accuracy: 0.9971 - dice_coef: 0.9314 - loss: 0.0686 - val_accuracy: 0.9914 - val_dice_coef: 0.7429 - val_loss: 0.2619 - learning_rate: 1.0000e-05

# %%
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
u_net_loss,u_net_accuracy,u_net_dice_coef=model.evaluate(X_test,y_test)
print(f'Loss is {u_net_loss}')
print(f'Accuracy is {u_net_accuracy}')
print(f'Dice_Coef is {u_net_dice_coef}')
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.9921 - dice_coef: 0.7410 - loss: 0.2594
# Loss is 0.2646293342113495
# Accuracy is 0.9918291568756104
# Dice_Coef is 0.7396136522293091

# %% [markdown]
# # ***Prediction***

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(np.uint8)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step

# %%
for i in range(10):
    
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 3, 1)
    plt.title("Image")
    plt.imshow(X_test[i],cmap='gray')
    
    plt.subplot(1, 3, 2)
    plt.title("True Mask")
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    
    plt.subplot(1, 3, 3)
    plt.title("Predicted Mask")
    plt.imshow(y_pred[i].squeeze(), cmap='gray')
    
    plt.show()
